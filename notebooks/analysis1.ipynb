# %% [markdown]
# # Aaditya Golash

# %%
import panda as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 import panda as pd
#
# ModuleNotFoundError: No module named 'panda'

# %%
import pandas as pd
pandas.__version__
# Out:
# '1.4.3'

# %%
dataset = pd.read_csv(r"C:\Users\Aaditya\Downloads\pg41\2016.csv")
dataset.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %% [markdown]
# ## Research question/interests
#
# Briefly describe your research question or interests here.
#
# I am interested in researching this topic, happiness because happiness is such an important emotion. It affects everything we do. Almost anything we do is to either make ourselves or others happy and everything we do directly or indirectly affects our happiness. It is a powerful emotion and this data which shows the factors what affects happiness provides extremely valuable information to the stakeholders whether that be companies or businesses or the governing bodies. As it is an emotion, happiness isn’t exactly quantifiable. This dataset is a very good example at what a possible way would be to quantify this emotion. These are some of the reasons why i am interested in this dataset.
# Freedom is understood as either having the ability to act or change without constraint or to possess the power and resources to fulfill one's purposes unhindered. My research question is How does a country’s freedom affect it’s happiness? . I am going to examine how the trends in freedom and happiness change over the selected timeframe.

# %%
import numpy as np
import pandas as pd

data1 = pd.read_csv("C:\\Users\\athar\\Documents\\COSC 301\\project-group41\\data\\raw\\2015.csv")
data1.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0  Switzerland               1            7.587                   1.39651
# 1      Iceland               2            7.561                   1.30232
# 2      Denmark               3            7.527                   1.32548
# 3       Norway               4            7.522                   1.45900
# 4       Canada               5            7.427                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# ...

# %%
data2 = pd.read_csv("C:\\Users\\athar\\Documents\\COSC 301\\project-group41\\data\\raw\\2016.csv")
data2.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0      Denmark               1            7.526                   1.44178
# 1  Switzerland               2            7.509                   1.52733
# 2      Iceland               3            7.501                   1.42666
# 3       Norway               4            7.498                   1.57744
# 4      Finland               5            7.413                   1.40598
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.16374                   0.79504  0.57941                        0.44453
# 1  1.14524                   0.86303  0.58557                        0.41203
# 2  1.18326                   0.86733  0.56624                        0.14975
# 3  1.12690                   0.79579  0.59609                        0.35776
# 4  1.13464                   0.81091  0.57104                        0.41004
#
#    Generosity  Dystopia Residual
# ...

# %%
data3 = pd.read_csv("C:\\Users\\athar\\Documents\\COSC 301\\project-group41\\data\\raw\\2017.csv")
data3.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0       Norway               1            7.537                   1.61646
# 1      Denmark               2            7.522                   1.48238
# 2      Iceland               3            7.504                   1.48063
# 3  Switzerland               4            7.494                   1.56498
# 4      Finland               5            7.469                   1.44357
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.53352                   0.79667  0.63542                        0.31596
# 1  1.55112                   0.79257  0.62601                        0.40077
# 2  1.61057                   0.83355  0.62716                        0.15353
# 3  1.51691                   0.85813  0.62007                        0.36701
# 4  1.54025                   0.80916  0.61795                        0.38261
#
#    Generosity  Dystopia Residual
# ...

# %%
merged1 = pd.merge(data1, data2, how="outer")
merged1
# Out:
#          Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0    Switzerland               1            7.587                   1.39651
# 1        Iceland               2            7.561                   1.30232
# 2        Denmark               3            7.527                   1.32548
# 3         Norway               4            7.522                   1.45900
# 4         Canada               5            7.427                   1.32629
# ..           ...             ...              ...                       ...
# 310        Benin             153            3.484                   0.39499
# 311  Afghanistan             154            3.360                   0.38227
# 312         Togo             155            3.303                   0.28123
# 313        Syria             156            3.069                   0.74719
# 314      Burundi             157            2.905                   0.06831
#
#       Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
merged2 = pd.merge(merged1, data3, how="outer")
merged2
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 0                 Switzerland               1            7.587
# 1                     Iceland               2            7.561
# 2                     Denmark               3            7.527
# 3                      Norway               4            7.522
# 4                      Canada               5            7.427
# ..                        ...             ...              ...
# 465                    Rwanda             151            3.471
# 466                     Syria             152            3.462
# 467                  Tanzania             153            3.349
# 468                   Burundi             154            2.905
# 469  Central African Republic             155            2.693
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# ...
