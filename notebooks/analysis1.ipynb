# %% [markdown]
# # Aaditya Golash

# %%
import pandas as pd

# %%
import pandas as pd
pd.__version__

# %%
dataset = pd.read_csv("../data/raw/2016.csv")
dataset.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %% [markdown]
# ## Research question/interests
#
# Briefly describe your research question or interests here.
#
# I am interested in researching this topic, happiness because happiness is such an important emotion. It affects everything we do. Almost anything we do is to either make ourselves or others happy and everything we do directly or indirectly affects our happiness. It is a powerful emotion and this data which shows the factors what affects happiness provides extremely valuable information to the stakeholders whether that be companies or businesses or the governing bodies. As it is an emotion, happiness isn’t exactly quantifiable. This dataset is a very good example at what a possible way would be to quantify this emotion. These are some of the reasons why i am interested in this dataset.
# Freedom is understood as either having the ability to act or change without constraint or to possess the power and resources to fulfill one's purposes unhindered. My research question is How does a country’s freedom affect it’s happiness? . I am going to examine how the trends in freedom and happiness change over the selected timeframe.

# %%
import numpy as np
import pandas as pd

data1 = pd.read_csv("../data/raw/2015.csv")
data1.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0  Switzerland               1            7.587                   1.39651
# 1      Iceland               2            7.561                   1.30232
# 2      Denmark               3            7.527                   1.32548
# 3       Norway               4            7.522                   1.45900
# 4       Canada               5            7.427                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# ...

# %%
import numpy as np
import pandas as pd
data2 = pd.read_csv("../data/raw/2016.csv")
data2.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0      Denmark               1            7.526                   1.44178
# 1  Switzerland               2            7.509                   1.52733
# 2      Iceland               3            7.501                   1.42666
# 3       Norway               4            7.498                   1.57744
# 4      Finland               5            7.413                   1.40598
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.16374                   0.79504  0.57941                        0.44453
# 1  1.14524                   0.86303  0.58557                        0.41203
# 2  1.18326                   0.86733  0.56624                        0.14975
# 3  1.12690                   0.79579  0.59609                        0.35776
# 4  1.13464                   0.81091  0.57104                        0.41004
#
#    Generosity  Dystopia Residual
# ...

# %%
import numpy as np
import pandas as pd
data3 = pd.read_csv("../data/raw/2017.csv")
data3.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0       Norway               1            7.537                   1.61646
# 1      Denmark               2            7.522                   1.48238
# 2      Iceland               3            7.504                   1.48063
# 3  Switzerland               4            7.494                   1.56498
# 4      Finland               5            7.469                   1.44357
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.53352                   0.79667  0.63542                        0.31596
# 1  1.55112                   0.79257  0.62601                        0.40077
# 2  1.61057                   0.83355  0.62716                        0.15353
# 3  1.51691                   0.85813  0.62007                        0.36701
# 4  1.54025                   0.80916  0.61795                        0.38261
#
#    Generosity  Dystopia Residual
# ...

# %%
import numpy as np
import pandas as pd

data2 = pd.read_csv("../data/raw/2016.csv")
data1 = pd.read_csv("../data/raw/2015.csv")
merged1 = pd.merge(data1, data2, how="outer")
merged1.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0  Switzerland               1            7.587                   1.39651
# 1      Iceland               2            7.561                   1.30232
# 2      Denmark               3            7.527                   1.32548
# 3       Norway               4            7.522                   1.45900
# 4       Canada               5            7.427                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# ...

# %%
import numpy as np
import pandas as pd

data1 = pd.read_csv("../data/raw/2015.csv")
data2 = pd.read_csv("../data/raw/2016.csv")
data3 = pd.read_csv("../data/raw/2017.csv")
merged1 = pd.merge(data1, data2, how="outer")
merged2 = pd.merge(merged1, data3, how="outer")
merged2.to_csv('merged.csv',index=False)
print(merged2)
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 0                 Switzerland               1            7.587
# 1                     Iceland               2            7.561
# 2                     Denmark               3            7.527
# 3                      Norway               4            7.522
# 4                      Canada               5            7.427
# ..                        ...             ...              ...
# 465                    Rwanda             151            3.471
# 466                     Syria             152            3.462
# 467                  Tanzania             153            3.349
# 468                   Burundi             154            2.905
# 469  Central African Republic             155            2.693
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# ...

# %% [markdown]
# ## MILESTONE 3
# ### TASK 1:
# #### EDA. I will be using the most recent dataset 2017

# %%
import numpy as np
import pandas as pd

data3= pd.read_csv("../data/raw/2017.csv")
data3.info()
print()

print("General stats:")

data3.describe()

data3 = data3.dropna()
data3 = data3.reset_index()
data3 = data3.drop(columns=["index" ])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness Rank                 155 non-null    int64
#  2   Happiness Score                155 non-null    float64
#  3   Economy (GDP per Capita)       155 non-null    float64
#  4   Family                         155 non-null    float64
#  5   Health (Life Expectancy)       155 non-null    float64
#  6   Freedom                        155 non-null    float64
#  7   Trust (Government Corruption)  155 non-null    float64
#  8   Generosity                     155 non-null    float64
#  9   Dystopia Residual              155 non-null    float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 12.2+ KB
#
# General stats:
# ...

# %% [markdown]
# #### Relation between the columns

# %%
import seaborn as sns
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
data3= pd.read_csv("../data/raw/2017.csv")
r = data3.corr()
r.describe()
# Out:
#        Happiness Rank  Happiness Score  Economy (GDP per Capita)    Family  \
# count        9.000000         9.000000                  9.000000  9.000000
# mean        -0.433117         0.442689                  0.361847  0.343928
# std          0.595009         0.593636                  0.568827  0.516625
# min         -0.992774        -0.992774                 -0.813243 -0.736752
# 25%         -0.780717         0.429074                  0.024226  0.070507
# 50%         -0.551607         0.570137                  0.369874  0.424965
# 75%         -0.405837         0.781952                  0.812468  0.688296
# max          1.000000         1.000000                  1.000000  1.000000
#
#        Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# count                  9.000000  9.000000                       9.000000
# mean                   0.356013  0.340043                       0.295150
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
data3= pd.read_csv("../data/raw/2017.csv")
data3 = data3.dropna()
r = data3.corr()
r.describe()
ax = plt.axes()
sns.heatmap(r, xticklabels=r.columns, yticklabels=r.columns, annot=True,ax=ax, cmap=sns.diverging_palette(500, 0, as_cmap=True))


ax.set_title('Correlation visualisation via Heatmap')
results_path = 'A1heatmap.png'
print(results_path)
plt.savefig(results_path)
# Out:
# A1heatmap.png

# %% [markdown]
# ### From the heatmap visualisations, we can see that freedom has an above average correlation to Happiness Rank and Happiness Score. As Freedom has a correlation of 0.55 to Happiness Rank and 0.57 to Happiness Score.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
data3= pd.read_csv("../data/raw/2017.csv")
data3.nunique(axis=0)
data3.describe().apply(lambda s: s.apply(lambda x: format(x, 'f')))
# Out:
#       Happiness Rank Happiness Score Economy (GDP per Capita)      Family  \
# count     155.000000      155.000000               155.000000  155.000000
# mean       78.000000        5.354019                 0.984718    1.188897
# std        44.888751        1.131230                 0.420793    0.287263
# min         1.000000        2.693000                 0.000000    0.000000
# 25%        39.500000        4.505500                 0.663370    1.042635
# 50%        78.000000        5.279000                 1.064580    1.253920
# 75%       116.500000        6.101500                 1.318030    1.414315
# max       155.000000        7.537000                 1.870770    1.610570
#
#       Health (Life Expectancy)     Freedom Trust (Government Corruption)  \
# count               155.000000  155.000000                    155.000000
# mean                  0.551341    0.408786                      0.123120
# std                   0.237073    0.149997                      0.101661
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
data3 = pd.read_csv("../data/raw/2017.csv")
data3.dropna()
y = sns.jointplot(x="Freedom", y='Happiness Score', data=data3, kind="reg")
y.fig.suptitle( "Jointplot of Happiness Score vs Freedom" , size = 10 )
results_path2 = 'A1jointplot.png'
#print(results_path)
plt.savefig(results_path2)

# %% [markdown]
# #### We see a correlation that higher freedom is higher happiness score. We can notice this from the scatterplot above, as we can see that there are more points upwards and towards the right indicating a positive relationship between the two. The higher the freedom the higher the happiness score. Even along the line we see positive relationship.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
data3 = pd.read_csv("../data/raw/2017.csv")
data3.dropna()
data3.plot(kind='scatter', x='Freedom', y='Happiness Score').set(title="Scatterplot of Happiness Score vs Freedom")
#y.fig.suptitle( "Scatterplot of Happiness Score vs Freedom" , size = 16 )
results_path = 'A1scatterplot.png'
print(results_path)
plt.savefig(results_path)
# Out:
# C:\Users\Aaditya\miniconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# A1scatterplot.png

# %% [markdown]
# #### We see a correlation that higher freedom is higher happiness and higher rank from the concentration of points.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
data3 = pd.read_csv("../data/raw/2017.csv")
data3.dropna()
x= sns.jointplot(data=data3, x="Freedom", y="Happiness Score", kind="hex", color="#4CB391")
x.fig.suptitle( "Hexagonal Jointplot of Happiness Score vs Freedom" , size = 10 )
results_path = 'A1hexplot.png'
#print(results_path)
plt.savefig(results_path)

# %% [markdown]
# #### We see a correlation that higher freedom is higher happiness score. We can notice this from the hexplot above, as we can see that it is more darker upwards and towards the right indicating a positive relationship between the two. The higher the freedom the higher the happiness score. Even along the line we see positive relationship.

# %% [markdown]
# ### Summary and conclusions from graphs

# %% [markdown]
# #### **Research Question :** How does a country’s freedom affect it’s happiness?
#
#
#  ####   - Summary of findings, insight, and conclusions
# ####    - I hypothesised that freedom and happiness are directly related.
# ####    - From the heatmap we notice that freedom has an above average correlation to Happiness Rank and Happiness Score. As Freedom has a correlation           of 0.55 to Happiness Rank and 0.57 to Happiness Score.
# ####    - From the scatterplot we see a correlation that higher freedom is higher happiness and higher rank from the concentration of points.
#  ####   - From the joinplot we see a correlation that higher freedom is higher happiness score. We can notice this from the scatterplot above, as we can see that there are more points upwards and towards the right indicating a positive relationship between the two. The higher the freedom the higher the happiness score. Even along the line we see positive relationship.
#  ####   - From the hexplot :We can notice this from the hexplot above, as we can see that it is more darker upwards and towards the right indicating a positive relationship between the two. The higher the freedom the higher the happiness score. Even along the line we see positive relationship.

# %% [markdown]
# ## TASK 2:

# %% [markdown]
# #### Removing the columns I am not going to use. To clear it up.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
data3 = pd.read_csv("../data/raw/2017.csv")
data2 = pd.read_csv("../data/raw/2016.csv")
data1 = pd.read_csv("../data/raw/2015.csv")
clean_data1 = data1.drop(columns=['Trust (Government Corruption)','Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Generosity'])

clean_data2 = data2.drop(columns=['Trust (Government Corruption)','Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Generosity'])

clean_data3 = data3.drop(columns=['Trust (Government Corruption)','Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Generosity'])
clean_data1.to_csv('d1aaditya.csv',index=False)
clean_data2.to_csv('d2aaditya.csv',index=False)
clean_data3.to_csv('d3aaditya.csv',index=False)

# %% [markdown]
# #### Renaming the columns to make easier to use

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
data3 = pd.read_csv(r"C:\Users\Aaditya\COSC301\project-group41\data\raw\2017.csv")
data2 = pd.read_csv(r"C:\Users\Aaditya\COSC301\project-group41\data\raw\2016.csv")
data1 = pd.read_csv(r"C:\Users\Aaditya\COSC301\project-group41\data\raw\2015.csv")
clean_data1.rename(columns={"Happiness Score": "2015 HS", "Happiness Rank": "2015 Rank", "Freedom": "15Free", "Dystopia Residual": "2015 DysRes"}, inplace=True)

clean_data2.rename(columns={"Happiness Score": "2016 HS", "Happiness Rank": "2016 Rank", "Freedom": "16Free", "Dystopia Residual": "2016 DysRes"}, inplace=True)

clean_data3.rename(columns={"Happiness Score": "2017 HS", "Happiness Rank": "2017 Rank", "Freedom": "17Free", "Dystopia Residual": "2017 DysRes"}, inplace=True)

# %% [markdown]
# #### Timeseries for the countries

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
data3 =pd.read_csv("../data/raw/2017.csv")
data2 = pd.read_csv("../data/raw/2016.csv")
data1 = pd.read_csv("../data/raw/2015.csv")
clean_data1.rename(columns={"Happiness Score": "2015 HS", "Happiness Rank": "2015 Rank", "Freedom": "15Free", "Dystopia Residual": "2015 DysRes"}, inplace=True)

clean_data2.rename(columns={"Happiness Score": "2016 HS", "Happiness Rank": "2016 Rank", "Freedom": "16Free", "Dystopia Residual": "2016 DysRes"}, inplace=True)

clean_data3.rename(columns={"Happiness Score": "2017 HS", "Happiness Rank": "2017 Rank", "Freedom": "17Free", "Dystopia Residual": "2017 DysRes"}, inplace=True)
tseries = pd.merge(clean_data1, clean_data2, how="left", on="Country")
tseries = pd.merge(tseries, clean_data3, how="left", on="Country")

tseries = tseries.dropna() #Used to drop any rows which had null values

tseries.to_csv("../data/processed/merged_data.csv")

tseries.head()
# Out:
#        Country  2015 Rank  2015 HS   15Free  2015 DysRes  2016 Rank  2016 HS  \
# 0  Switzerland          1    7.587  0.66557      2.51738        2.0    7.509
# 1      Iceland          2    7.561  0.62877      2.70201        3.0    7.501
# 2      Denmark          3    7.527  0.64938      2.49204        1.0    7.526
# 3       Norway          4    7.522  0.66973      2.46531        4.0    7.498
# 4       Canada          5    7.427  0.63297      2.45176        6.0    7.404
#
#     16Free  2016 DysRes  2017 Rank  2017 HS   17Free  2017 DysRes
# 0  0.58557      2.69463        4.0    7.494  0.62007      2.27672
# 1  0.56624      2.83137        3.0    7.504  0.62716      2.32272
# 2  0.57941      2.73939        2.0    7.522  0.62601      2.31371
# 3  0.59609      2.66465        1.0    7.537  0.63542      2.27703
# 4  0.57370      2.70485        7.0    7.316  0.61110      2.18726

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
data3 =pd.read_csv("../data/raw/2017.csv")
data2 = pd.read_csv("../data/raw/2016.csv")
data1 = pd.read_csv("../data/raw/2015.csv")
clean_data1.rename(columns={"Happiness Score": "2015 HS", "Happiness Rank": "2015 Rank", "Freedom": "15Free", "Dystopia Residual": "2015 DysRes"}, inplace=True)

clean_data2.rename(columns={"Happiness Score": "2016 HS", "Happiness Rank": "2016 Rank", "Freedom": "16Free", "Dystopia Residual": "2016 DysRes"}, inplace=True)

clean_data3.rename(columns={"Happiness Score": "2017 HS", "Happiness Rank": "2017 Rank", "Freedom": "17Free", "Dystopia Residual": "2017 DysRes"}, inplace=True)
tseries = pd.merge(clean_data1, clean_data2, how="left", on="Country")
tseries = pd.merge(tseries, clean_data3, how="left", on="Country")

tseries = tseries.dropna() #Used to drop any rows which had null values

tseries["AvgDysRes"] = ((tseries["2015 DysRes"] + tseries["2016 DysRes"] + tseries["2017 DysRes"]) / 3)

tseries = tseries.drop(columns=["2015 DysRes" ])
tseries = tseries.drop(columns=["2016 DysRes" ])
tseries = tseries.drop(columns=["2017 DysRes" ])

tseries.head()
# Out:
#        Country  2015 Rank  2015 HS   15Free  2016 Rank  2016 HS   16Free  \
# 0  Switzerland          1    7.587  0.66557        2.0    7.509  0.58557
# 1      Iceland          2    7.561  0.62877        3.0    7.501  0.56624
# 2      Denmark          3    7.527  0.64938        1.0    7.526  0.57941
# 3       Norway          4    7.522  0.66973        4.0    7.498  0.59609
# 4       Canada          5    7.427  0.63297        6.0    7.404  0.57370
#
#    2017 Rank  2017 HS   17Free  AvgDysRes
# 0        4.0    7.494  0.62007   2.496243
# 1        3.0    7.504  0.62716   2.618700
# 2        2.0    7.522  0.62601   2.515047
# 3        1.0    7.537  0.63542   2.468997
# 4        7.0    7.316  0.61110   2.447957

# %% [markdown]
# #### What i'm doing here is to change all 3 DysRes columns to one to find an average to make it easier to compute and use just like my teammate.

# %% [markdown]
# ## TASK 3

# %%
import project_functions1 as p1 

timeseries = p1.landp(r"../data/raw/2015.csv", r"../data/raw/2016.csv", r"../data/raw/2017.csv")
timeseries.head()
# Out:
#        Country  2015 Rank  2015 HS   15Free  2016 Rank  2016 HS   16Free  \
# 0  Switzerland          1    7.587  0.66557        2.0    7.509  0.58557
# 1      Iceland          2    7.561  0.62877        3.0    7.501  0.56624
# 2      Denmark          3    7.527  0.64938        1.0    7.526  0.57941
# 3       Norway          4    7.522  0.66973        4.0    7.498  0.59609
# 4       Canada          5    7.427  0.63297        6.0    7.404  0.57370
#
#    2017 Rank  2017 HS   17Free     AvgDR
# 0        4.0    7.494  0.62007  2.496243
# 1        3.0    7.504  0.62716  2.618700
# 2        2.0    7.522  0.62601  2.515047
# 3        1.0    7.537  0.63542  2.468997
# 4        7.0    7.316  0.61110  2.447957

# %% [markdown]
# #### Output should be same as task 2 because basically method is defined in a different file and then imported but basically the same.

# %%
import project_functions1 as p1 

timeseries = p1.landp(r"../data/raw/2015.csv", r"../data/raw/2016.csv", r"../data/raw/2017.csv")
r= timeseries.head()
r.corr()
# Out:
#            2015 Rank   2015 HS    15Free  2016 Rank   2016 HS    16Free  \
# 2015 Rank   1.000000 -0.934541 -0.207077   0.739795 -0.701889  0.084805
# 2015 HS    -0.934541  1.000000  0.402260  -0.776319  0.861897  0.151077
# 15Free     -0.207077  0.402260  1.000000  -0.315813  0.465558  0.954126
# 2016 Rank   0.739795 -0.776319 -0.315813   1.000000 -0.917160 -0.084450
# 2016 HS    -0.701889  0.861897  0.465558  -0.917160  1.000000  0.277247
# 16Free      0.084805  0.151077  0.954126  -0.084450  0.277247  1.000000
# 2017 Rank   0.274721 -0.582131 -0.527803   0.598421 -0.842360 -0.492113
# 2017 HS    -0.566273  0.808323  0.536267  -0.760321  0.955376  0.408497
# 17Free     -0.169464  0.503128  0.471560  -0.393172  0.711090  0.482349
# AvgDR      -0.587721  0.576067 -0.464737  -0.437166  0.480984 -0.610643
#
#            2017 Rank   2017 HS    17Free     AvgDR
# 2015 Rank   0.274721 -0.566273 -0.169464 -0.587721
# 2015 HS    -0.582131  0.808323  0.503128  0.576067
# ...

# %% [markdown]
# ## TASK 4

# %% [markdown]
# #### ANALYSIS OF DATA

# %% [markdown]
#  From the graphs in Task 1 we can see the correlation of freedom of the people of a country to the happiness score and hence happiness index. In atleast the most recent year, we can see that freedom and happiness are positively related. Let's take a look for other years.
#  We can see the correlation further with more visualisations:

# %%
import seaborn as sns
import project_functions1 as p1 

timeseries = p1.landp(r"../data/raw/2015.csv", r"../data/raw/2016.csv", r"../data/raw/2017.csv")
sns.pairplot(timeseries)

# %% [markdown]
#  Here we can see a scatterplot between all our variables. This shows us all the correlations and comparisions.
#  What we can see is that from the given values is that as the values on x axis go up, the values on y go up to. Thus we can infer that there is a positive relation.

# %%
import seaborn as sns
import project_functions1 as p1 

timeseries = p1.landp(r"../data/raw/2015.csv", r"../data/raw/2016.csv", r"../data/raw/2017.csv")
sns.pairplot(timeseries).set(title ="pairplot of timeseries function")

# %%
import seaborn as sns
import project_functions1 as p1 

timeseries = p1.landp(r"../data/raw/2015.csv", r"../data/raw/2016.csv", r"../data/raw/2017.csv")
x = sns.histplot(data=timeseries , y="15Free", x = "2015 HS").set(title='2015 Freedom vs Health Score')
results_path = 'A1hist15.png'
print(results_path)
plt.savefig(results_path)
# Out:
# A1hist15.png

# %% [markdown]
# We can see that there is a positive correlation between Health score and Freedom in 2015.

# %%
import seaborn as sns
import project_functions1 as p1 

timeseries = p1.landp(r"../data/raw/2015.csv", r"../data/raw/2016.csv", r"../data/raw/2017.csv")
y =sns.histplot(data=timeseries , y="16Free", x = "2016 HS").set(title='2016 Freedom vs Health Score')
results_path = 'A1hist16.png'
print(results_path)
plt.savefig(results_path)
# Out:
# A1hist16.png

# %% [markdown]
# We can see that there is a positive correlation between Health score and Freedom in 2016.

# %%
import seaborn as sns
import project_functions1 as p1 

timeseries = p1.landp(r"../data/raw/2015.csv", r"../data/raw/2016.csv", r"../data/raw/2017.csv")
a = sns.histplot(data=timeseries , y="17Free", x = "2017 HS").set(title='2017 Freedom vs Health Score')
results_path = 'A1hist17.png'
print(results_path)
plt.savefig(results_path)
# Out:
# A1hist17.png

# %% [markdown]
# We can see that there is a positive correlation between Health score and Freedom in 2017.

# %% [markdown]
# We can conclude from all 3 histplots above that in all 3 years of our data, there is a positive relation that is very similar every year. This indicates a trend which would mean that Freedom is positively  related to Health Score and this correlation is not weak.

# %%
import seaborn as sns
import project_functions as p1 
import matplotlib.pyplot as plt
timeseries = p1.landp(r"../data/raw/2015.csv", r"../data/raw/2016.csv", r"../data/raw/2017.csv")
ax = plt.axes()
x = timeseries.corr()
x.dropna()
sns.heatmap(x, xticklabels=r.columns, yticklabels=r.columns, annot=True,ax=ax)


ax.set_title('Correlation visualisation via Heatmap of timeseries')
results_path = 'A1heatmapT4.png'
print(results_path)
plt.savefig(results_path)
# Out:
# A1heatmapT4.png

# %% [markdown]
#  In this heatmap we see that there is a strong negative correlation between Health Rank and Freedom for 2015 and 2016 (-0.95) which is a good thing because lower rank would indicate a higher place on the dataset, which would mean more freedom results in better rank. However in 2017 it was quite different which gives us mixed results here.

# %% [markdown]
# ### SUMMARY:

# %% [markdown]
# - From the pairplot :
# We can see a scatterplot between all of our variables here. This displays all of the correlations and comparisons.
# What we can see from the given values is that as the values on the x axis increase, so do the values on the y axis. As a result, we can
#  - From the 3 scatterplots:
# We can see that there is a positive correlation between Health score and Freedom in 2015.We can see that there is a positive correlation between Health score and Freedom in 2016.We can see that there is a positive correlation between Health score and Freedom in 2017.
# - From the heatmap:
# In this heatmap we see that there is a strong negative correlation between Health Rank and Freedom for 2015 and 2016 (-0.95) which is a good thing because lower rank would indicate a higher place on the dataset, which would mean more freedom results in better rank. However in 2017 it was quite different which gives us mixed results here.
# - From results before:
# I hypothesised that freedom and happiness are inextricably linked.
#  According to the heatmap, freedom has an above-average correlation with Happiness Rank and Happiness Score. As Freedom has a 0.55 correlation with Happiness Rank and a 0.57 correlation with Happiness Score.
#  The scatterplot shows a correlation between higher freedom and higher happiness and rank based on point concentration.
#   According to the joinplot, greater freedom leads to a higher happiness score. We can see this from the scatterplot above, where there are more points pointing upwards and to the right, indicating a positive relationship between the two. The higher the level of freedom, the higher the level of happiness. Positive relationships can be found all the way down the line.
#  From the hexplot:We can see this from the hexplot above, as it is darker upwards and to the right, indicating a positive relationship between the two. The higher the level of freedom, the higher the level of happiness. Positive relationships can be found all the way down the line.

# %% [markdown]
# #### 1. Concept
#  The word ‘happiness’ is used in a number of ways. In this dataset the word is used to denote a sense of satisfaction with life.
#  In the broadest sense, freedom can be defined as an individual's ability to make choices, typically major life decisions. The 'ability' to choose necessitates the existence of a 'opportunity' to choose, which is a feature of the environment in which an individual lives.
#
# #### 2.Explanation:
#
#  What this all shows us is that the hypothesis that freedom is directly correlated to happiness ,and that higher freedom yields a higher happiness rank too is correct.
#  This means that countries should put an emphasis on listening to the people's wants and providing them with the freedom they need in order to have a happier populous.

# %% [markdown]
# ### CONCLUSION:

# %% [markdown]
# Thus, after analysing multiple graphs and factors that influence a country's happiness index, we conclude that freedom and happiness are positively correlated. Although there is some visualisation that suggest otherwisw, this is true for the most part.
