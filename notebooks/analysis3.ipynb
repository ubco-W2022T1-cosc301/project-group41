# %% [markdown]
# # Victoria Versteegh

# %% [markdown]
# ## Research question/interests
#
# Briefly describe your research question or interests here.

# %%
import numpy as np
import pandas as pd


pd.__version__
pd.read_csv(r"C:\Users\remit\Downloads\2015 (2).csv")
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
import pandas as pd

dataset = pd.read_csv(r"C:\Users\remit\Downloads\2018.csv")
dataset.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# ...

# %%
dataset = pd.read_csv(r"C:\Users\remit\Downloads\2019.csv")
dataset.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
import numpy as np
import pandas as pd

datasetone = pd.read_csv(r"C:\Users\remit\Downloads\2019.csv")
datasettwo = pd.read_csv(r"C:\Users\remit\Downloads\2018.csv")
result = pd.merge(
    datasetone, 
    datasettwo, 
    on = None,
    left_on=None,
    right_on=None,
    left_index=True,
    right_index=True,
    sort=True,
    suffixes= (' ',' '),
    copy=True,
    indicator=False,
    validate=None, )

print(result)
# Out:
#      Overall rank         Country or region   Score   GDP per capita   \
# 0                1                   Finland   7.769            1.340
# 1                2                   Denmark   7.600            1.383
# 2                3                    Norway   7.554            1.488
# 3                4                   Iceland   7.494            1.380
# 4                5               Netherlands   7.488            1.396
# ..             ...                       ...     ...              ...
# 151            152                    Rwanda   3.334            0.359
# 152            153                  Tanzania   3.231            0.476
# 153            154               Afghanistan   3.203            0.350
# 154            155  Central African Republic   3.083            0.026
# 155            156               South Sudan   2.853            0.306
#
#      Social support   Healthy life expectancy   Freedom to make life choices   \
# ...

# %%
import pandas as pd

file1 = (r"C:\Users\remit\Downloads\2019.csv")
file2 = (r"C:\Users\remit\Downloads\2018.csv")


# merge
dataFrame = pd.concat(
   map(pd.read_csv, [file1, file2]), ignore_index=True)
print(dataFrame)
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 307           152                     Yemen  3.355           0.442
# 308           153                  Tanzania  3.303           0.455
# 309           154               South Sudan  3.254           0.337
# 310           155  Central African Republic  3.083           0.024
# 311           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns#Understanding my variables

data_2015 = pd.read_csv(r"C:\Users\remit\Downloads\2015 (2).csv")


data_2015.shape
data_2015.head()
data_2015.columns


data_2015 = data_2015.copy().drop(['Generosity','Health (Life Expectancy)','Economy (GDP per Capita)', 'Trust (Government Corruption)', 'Region', 'Family'], axis=1)
data_2015.nunique(axis=0)
data_2015.describe().apply(lambda s: s.apply(lambda x: format(x, 'f')))
data_2015 = data_2015.dropna(axis=0)
data_2015.shape
data_2015
# Out:
#          Country  Happiness Rank  Happiness Score  Standard Error  Freedom  \
# 0    Switzerland               1            7.587         0.03411  0.66557
# 1        Iceland               2            7.561         0.04884  0.62877
# 2        Denmark               3            7.527         0.03328  0.64938
# 3         Norway               4            7.522         0.03880  0.66973
# 4         Canada               5            7.427         0.03553  0.63297
# ..           ...             ...              ...             ...      ...
# 153       Rwanda             154            3.465         0.03464  0.59201
# 154        Benin             155            3.340         0.03656  0.48450
# 155        Syria             156            3.006         0.05015  0.15684
# 156      Burundi             157            2.905         0.08658  0.11850
# 157         Togo             158            2.839         0.06727  0.36453
#
#      Dystopia Residual
# 0              2.51738
# ...

# %%
# calculate correlation matrix
corr = data_2015.corr()# plot the heatmap
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, cmap=sns.diverging_palette(220, 20, as_cmap=True))
# Out:
# <AxesSubplot:>

# %%
data_2015.plot(kind='scatter', x='Freedom', y='Happiness Score')
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Happiness Score'>

# %%
data_2015.info()
data_2015.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            158 non-null    object
#  1   Happiness Rank     158 non-null    int64
#  2   Happiness Score    158 non-null    float64
#  3   Standard Error     158 non-null    float64
#  4   Freedom            158 non-null    float64
#  5   Dystopia Residual  158 non-null    float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.5+ KB
#        Country  Happiness Rank  Happiness Score  Standard Error  Freedom  \
# 0  Switzerland               1            7.587         0.03411  0.66557
# 1      Iceland               2            7.561         0.04884  0.62877
# 2      Denmark               3            7.527         0.03328  0.64938
# 3       Norway               4            7.522         0.03880  0.66973
# ...

# %%
import pandas as pd
import numpy as np

def load_and_process():

    return df
    
    df = (
        pd.read_csv(
    r"C:\Users\remit\Downloads\2015 (2).csv", 
    usecols = ['Country', 'Happiness Rank', 'Happiness Score', 'Standard Error', 'Family', 'Freedom', 'Dystopia Residual']
)
.drop('Family', axis = 1)
.assign(
        testColumn = lambda x: x['Happiness Score'] + x['Standard Error']
    )
.rename(columns = {'Happiness Rank': 'Happy Rank'}) 
) 
    
    df
