# %% [markdown]
# # Atharva Jagtap

# %% [markdown]
# ## Research question/interests
#
# Briefly describe your research question or interests here.
#
# I am interested in the happiness report because I am curious to learn about how the trend in happiness changes over time and how people are affected by various factors.  The economy is defined as the wealth and resources of a country or region, especially in terms of the production and consumption of goods and services. With the economy being such an important part of our world, I am intrigued to find out how it affects happiness levels. Also, alongside the economy, how much the people trust in their government and its relation to happiness is another interesting thing I want to dwelve into. With such radical changes in the world today along with the growth of social media I want to know how this affects happiness levels and if is there any correlation between happiness and trust in government. My research question is: Does trust in the government and a stable economy really increase happiness?

# %%
import pandas as pd
import seaborn as sns

# %%
data1 = pd.read_csv("../data/raw/2015.csv")
data1
# Out:
#          Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0    Switzerland               1            7.587                   1.39651
# 1        Iceland               2            7.561                   1.30232
# 2        Denmark               3            7.527                   1.32548
# 3         Norway               4            7.522                   1.45900
# 4         Canada               5            7.427                   1.32629
# ..           ...             ...              ...                       ...
# 153       Rwanda             154            3.465                   0.22208
# 154        Benin             155            3.340                   0.28665
# 155        Syria             156            3.006                   0.66320
# 156      Burundi             157            2.905                   0.01530
# 157         Togo             158            2.839                   0.20868
#
#       Family  Health (Life Expectancy)  Freedom  \
# 0    1.34951                   0.94143  0.66557
# 1    1.40223                   0.94784  0.62877
# 2    1.36058                   0.87464  0.64938
# 3    1.33095                   0.88521  0.66973
# 4    1.32261                   0.90563  0.63297
# ..       ...                       ...      ...
# 153  0.77370                   0.42864  0.59201
# 154  0.35386                   0.31910  0.48450
# 155  0.47489                   0.72193  0.15684
# 156  0.41587                   0.22396  0.11850
# 157  0.13995                   0.28443  0.36453
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                          0.41978     0.29678            2.51738
# 1                          0.14145     0.43630            2.70201
# 2                          0.48357     0.34139            2.49204
# 3                          0.36503     0.34699            2.46531
# 4                          0.32957     0.45811            2.45176
# ..                             ...         ...                ...
# 153                        0.55191     0.22628            0.67042
# 154                        0.08010     0.18260            1.63328
# 155                        0.18906     0.47179            0.32858
# 156                        0.10062     0.19727            1.83302
# 157                        0.10731     0.16681            1.56726
#
# [158 rows x 10 columns]

# %%
data2 = pd.read_csv("../data/raw/2016.csv")
data2
# Out:
#          Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0        Denmark               1            7.526                   1.44178
# 1    Switzerland               2            7.509                   1.52733
# 2        Iceland               3            7.501                   1.42666
# 3         Norway               4            7.498                   1.57744
# 4        Finland               5            7.413                   1.40598
# ..           ...             ...              ...                       ...
# 152        Benin             153            3.484                   0.39499
# 153  Afghanistan             154            3.360                   0.38227
# 154         Togo             155            3.303                   0.28123
# 155        Syria             156            3.069                   0.74719
# 156      Burundi             157            2.905                   0.06831
#
#       Family  Health (Life Expectancy)  Freedom  \
# 0    1.16374                   0.79504  0.57941
# 1    1.14524                   0.86303  0.58557
# 2    1.18326                   0.86733  0.56624
# 3    1.12690                   0.79579  0.59609
# 4    1.13464                   0.81091  0.57104
# ..       ...                       ...      ...
# 152  0.10419                   0.21028  0.39747
# 153  0.11037                   0.17344  0.16430
# 154  0.00000                   0.24811  0.34678
# 155  0.14866                   0.62994  0.06912
# 156  0.23442                   0.15747  0.04320
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                          0.44453     0.36171            2.73939
# 1                          0.41203     0.28083            2.69463
# 2                          0.14975     0.47678            2.83137
# 3                          0.35776     0.37895            2.66465
# 4                          0.41004     0.25492            2.82596
# ..                             ...         ...                ...
# 152                        0.06681     0.20180            2.10812
# 153                        0.07112     0.31268            2.14558
# 154                        0.11587     0.17517            2.13540
# 155                        0.17233     0.48397            0.81789
# 156                        0.09419     0.20290            2.10404
#
# [157 rows x 10 columns]

# %%
data3 = pd.read_csv("../data/raw/2017.csv")
data3
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 0                      Norway               1            7.537
# 1                     Denmark               2            7.522
# 2                     Iceland               3            7.504
# 3                 Switzerland               4            7.494
# 4                     Finland               5            7.469
# ..                        ...             ...              ...
# 150                    Rwanda             151            3.471
# 151                     Syria             152            3.462
# 152                  Tanzania             153            3.349
# 153                   Burundi             154            2.905
# 154  Central African Republic             155            2.693
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.61646  1.53352                   0.79667  0.63542
# 1                     1.48238  1.55112                   0.79257  0.62601
# 2                     1.48063  1.61057                   0.83355  0.62716
# 3                     1.56498  1.51691                   0.85813  0.62007
# 4                     1.44357  1.54025                   0.80916  0.61795
# ..                        ...      ...                       ...      ...
# 150                   0.36875  0.94571                   0.32642  0.58184
# 151                   0.77715  0.39610                   0.50053  0.08154
# 152                   0.51114  1.04199                   0.36451  0.39002
# 153                   0.09162  0.62979                   0.15161  0.05990
# 154                   0.00000  0.00000                   0.01877  0.27084
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                          0.31596     0.36201            2.27703
# 1                          0.40077     0.35528            2.31371
# 2                          0.15353     0.47554            2.32272
# 3                          0.36701     0.29055            2.27672
# 4                          0.38261     0.24548            2.43018
# ..                             ...         ...                ...
# 150                        0.45522     0.25276            0.54006
# 151                        0.15135     0.49366            1.06157
# 152                        0.06604     0.35426            0.62113
# 153                        0.08415     0.20444            1.68302
# 154                        0.05657     0.28088            2.06600
#
# [155 rows x 10 columns]

# %% [markdown]
# ## Milestone 3
#
# ### Task 1: EDA
#
# First, we'll get familiar with our dataset.
#
# Since all 3 of our datasets have similar columns I am going to work on one dataframe for the sake of simplicity and do a joint analysis in the further tasks.

# %%
data1.info()
print()

print("General stats:")

data1.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Happiness Rank                 158 non-null    int64
#  2   Happiness Score                158 non-null    float64
#  3   Economy (GDP per Capita)       158 non-null    float64
#  4   Family                         158 non-null    float64
#  5   Health (Life Expectancy)       158 non-null    float64
#  6   Freedom                        158 non-null    float64
#  7   Trust (Government Corruption)  158 non-null    float64
#  8   Generosity                     158 non-null    float64
#  9   Dystopia Residual              158 non-null    float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 12.5+ KB
#
# General stats:
#        Happiness Rank  Happiness Score  Economy (GDP per Capita)      Family  \
# count      158.000000       158.000000                158.000000  158.000000
# mean        79.493671         5.375734                  0.846137    0.991046
# std         45.754363         1.145010                  0.403121    0.272369
# min          1.000000         2.839000                  0.000000    0.000000
# 25%         40.250000         4.526000                  0.545808    0.856823
# 50%         79.500000         5.232500                  0.910245    1.029510
# 75%        118.750000         6.243750                  1.158448    1.214405
# max        158.000000         7.587000                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                158.000000  158.000000                     158.000000
# mean                   0.630259    0.428615                       0.143422
# std                    0.247078    0.150693                       0.120034
# min                    0.000000    0.000000                       0.000000
# 25%                    0.439185    0.328330                       0.061675
# 50%                    0.696705    0.435515                       0.107220
# 75%                    0.811013    0.549092                       0.180255
# max                    1.025250    0.669730                       0.551910
#
#        Generosity  Dystopia Residual
# count  158.000000         158.000000
# mean     0.237296           2.098977
# std      0.126685           0.553550
# min      0.000000           0.328580
# 25%      0.150553           1.759410
# 50%      0.216130           2.095415
# 75%      0.309883           2.462415
# max      0.795880           3.602140

# %%
sns.set_theme(style="dark")

# %% [markdown]
# Let us find out how different columns in our dataset correlate with each other;

# %%
relation = data1.corr(numeric_only=True)
relation
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Economy (GDP per Capita)    Family  \
# Happiness Rank                                -0.785267 -0.733644
# Happiness Score                                0.780966  0.740605
# Economy (GDP per Capita)                       1.000000  0.645299
# Family                                         0.645299  1.000000
# Health (Life Expectancy)                       0.816478  0.531104
# Freedom                                        0.370300  0.441518
# Trust (Government Corruption)                  0.307885  0.205605
# Generosity                                    -0.010465  0.087513
# Dystopia Residual                              0.040059  0.148117
#
#                                Health (Life Expectancy)   Freedom  \
# Happiness Rank                                -0.735613 -0.556886
# Happiness Score                                0.724200  0.568211
# Economy (GDP per Capita)                       0.816478  0.370300
# Family                                         0.531104  0.441518
# Health (Life Expectancy)                       1.000000  0.360477
# Freedom                                        0.360477  1.000000
# Trust (Government Corruption)                  0.248335  0.493524
# Generosity                                     0.108335  0.373916
# Dystopia Residual                              0.018979  0.062783
#
#                                Trust (Government Corruption)  Generosity  \
# Happiness Rank                                     -0.372315   -0.160142
# Happiness Score                                     0.395199    0.180319
# Economy (GDP per Capita)                            0.307885   -0.010465
# Family                                              0.205605    0.087513
# Health (Life Expectancy)                            0.248335    0.108335
# Freedom                                             0.493524    0.373916
# Trust (Government Corruption)                       1.000000    0.276123
# Generosity                                          0.276123    1.000000
# Dystopia Residual                                  -0.033105   -0.101301
#
#                                Dystopia Residual
# Happiness Rank                         -0.521999
# Happiness Score                         0.530474
# Economy (GDP per Capita)                0.040059
# Family                                  0.148117
# Health (Life Expectancy)                0.018979
# Freedom                                 0.062783
# Trust (Government Corruption)          -0.033105
# Generosity                             -0.101301
# Dystopia Residual                       1.000000

# %%
sns.heatmap(relation, annot=True, cmap="afmhot", linecolor="white", linewidths=1)
# Out:
# <AxesSubplot: >

# %% [markdown]
# In the above heatmap we notice an intresting finding where the **economy** of the country has a **high correlation** with **happiness score** compared to the other parameters.

# %%
sns.jointplot(x="Economy (GDP per Capita)", y='Happiness Score', data=data1, kind="reg")

# %% [markdown]
# As we can see here, it is obvious that the **higher the economy** of the country the **greater is the happiness score**, it is linearly dependant.

# %%
sns.jointplot(x="Economy (GDP per Capita)", y='Happiness Score', hue="Trust (Government Corruption)", data=data1)

# %% [markdown]
# According to this plot we also notice that the **economy** and the peoples **trust in the government** are somewhat related to one another as a **greater trust** also implies a **better economy (a few exceptions)**.

# %% [markdown]
# ### Task 2: Set up an “Analysis Pipeline”
#
# #### 1. Load Data
#
# We have already done so in the beginning of the file.
#
# #### 2. Clean Data
#
# Since we have 3 years worth of consecutive time series data, we will first clean and drop the columns which we do not need.
# We are going to base our research on the economy and trust in the government, and hence we'll keep those and their related columns in our set.

# %%
clean_data1 = data1.drop(columns=['Happiness Rank', 'Family', 'Health (Life Expectancy)', 'Freedom', "Generosity"])

clean_data2 = data2.drop(columns=['Happiness Rank', 'Family', 'Health (Life Expectancy)', 'Freedom', "Generosity"])

clean_data3 = data3.drop(columns=['Happiness Rank', 'Family', 'Health (Life Expectancy)', 'Freedom', "Generosity"])

# %% [markdown]
# Now we will rename the columns in each set to match the year in which they were recorded, and shorten their names for easy access.

# %%
clean_data1.rename(columns={"Happiness Score": "2015 Score", "Economy (GDP per Capita)": "2015 GDP", "Trust (Government Corruption)": "2015 Trust", "Dystopia Residual": "2015 Dystopia Residual"}, inplace=True)

clean_data2.rename(columns={"Happiness Score": "2016 Score", "Economy (GDP per Capita)": "2016 GDP", "Trust (Government Corruption)": "2016 Trust", "Dystopia Residual": "2016 Dystopia Residual"}, inplace=True)

clean_data3.rename(columns={"Happiness Score": "2017 Score", "Economy (GDP per Capita)": "2017 GDP", "Trust (Government Corruption)": "2017 Trust", "Dystopia Residual": "2017 Dystopia Residual"}, inplace=True)

# %% [markdown]
# Then we will merge these datasets into one frame which gives us a time series of information for each country.

# %%
timeseries = pd.merge(clean_data1, clean_data2, how="left", on="Country")
timeseries = pd.merge(timeseries, clean_data3, how="left", on="Country")

timeseries = timeseries.dropna() #Used to drop any rows which had null values

timeseries.head()
# Out:
#        Country  2015 Score  2015 GDP  2015 Trust  2015 Dystopia Residual  \
# 0  Switzerland       7.587   1.39651     0.41978                 2.51738
# 1      Iceland       7.561   1.30232     0.14145                 2.70201
# 2      Denmark       7.527   1.32548     0.48357                 2.49204
# 3       Norway       7.522   1.45900     0.36503                 2.46531
# 4       Canada       7.427   1.32629     0.32957                 2.45176
#
#    2016 Score  2016 GDP  2016 Trust  2016 Dystopia Residual  2017 Score  \
# 0       7.509   1.52733     0.41203                 2.69463       7.494
# 1       7.501   1.42666     0.14975                 2.83137       7.504
# 2       7.526   1.44178     0.44453                 2.73939       7.522
# 3       7.498   1.57744     0.35776                 2.66465       7.537
# 4       7.404   1.44015     0.31329                 2.70485       7.316
#
#    2017 GDP  2017 Trust  2017 Dystopia Residual
# 0   1.56498     0.36701                 2.27672
# 1   1.48063     0.15353                 2.32272
# 2   1.48238     0.40077                 2.31371
# 3   1.61646     0.31596                 2.27703
# 4   1.47920     0.28737                 2.18726

# %% [markdown]
# #### 3. Process Data
#
# For this section we will first create a column for the average Dystopia Residual of the 3 years. Dystopia Residual is the hypothetical happiness score of the country with the worst values across its parameters, it is used in order to set a benchmark for comparision.

# %%
timeseries["AvgDR"] = ((timeseries["2015 Dystopia Residual"] + timeseries["2016 Dystopia Residual"] + timeseries["2017 Dystopia Residual"]) / 3)

timeseries = timeseries.drop(columns=["2015 Dystopia Residual", "2016 Dystopia Residual", "2017 Dystopia Residual"])

timeseries.head()
# Out:
#        Country  2015 Score  2015 GDP  2015 Trust  2016 Score  2016 GDP  \
# 0  Switzerland       7.587   1.39651     0.41978       7.509   1.52733
# 1      Iceland       7.561   1.30232     0.14145       7.501   1.42666
# 2      Denmark       7.527   1.32548     0.48357       7.526   1.44178
# 3       Norway       7.522   1.45900     0.36503       7.498   1.57744
# 4       Canada       7.427   1.32629     0.32957       7.404   1.44015
#
#    2016 Trust  2017 Score  2017 GDP  2017 Trust     AvgDR
# 0     0.41203       7.494   1.56498     0.36701  2.496243
# 1     0.14975       7.504   1.48063     0.15353  2.618700
# 2     0.44453       7.522   1.48238     0.40077  2.515047
# 3     0.35776       7.537   1.61646     0.31596  2.468997
# 4     0.31329       7.316   1.47920     0.28737  2.447957

# %% [markdown]
# ### Task 3: Method Chaining and writing Python programs
#
# Now we will make a method chain for the processes we did in task 2.

# %%
import project_functions2 as p2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [16], line 1
# ----> 1 import project_functions2 as p2
#
# File c:\Users\athar\Documents\COSC 301\project-group41\notebooks\project_functions2.py:36
#      24     timeseries = (
#      25         pd.merge(timeseries, clean_data3, how="left", on="Country")
#      26         .dropna()
#    (...)
#      30         .drop(columns=["2015 Dystopia Residual", "2016 Dystopia Residual", "2017 Dystopia Residual"])
#      31     )
#      33     return timeseries
# ---> 36 s = load_and_process("../data/raw/2015.csv", "../data/raw/2016.csv", "../data/raw/2017.csv")
#      37 s.head()
#
# File c:\Users\athar\Documents\COSC 301\project-group41\notebooks\project_functions2.py:23, in load_and_process(file1, file2, file3)
#      11 data2 = (
#      12     pd.read_csv(f"{file2}")
#      13     .drop(columns=['Happiness Rank', 'Family', 'Health (Life Expectancy)', 'Freedom', "Generosity"])
#      14     .rename(columns={"Happiness Score": "2016 Score", "Economy (GDP per Capita)": "2016 GDP", "Trust (Government Corruption)": "2016 Trust", "Dystopia Residual": "2016 Dystopia Residual"})
#      15 )
#      17 data3 = (
#      18     pd.read_csv(f"{file3}")
#      19     .drop(columns=['Happiness Rank', 'Family', 'Health (Life Expectancy)', 'Freedom', "Generosity"])
#      20     .rename(columns={"Happiness Score": "2017 Score", "Economy (GDP per Capita)": "2017 GDP", "Trust (Government Corruption)": "2017 Trust", "Dystopia Residual": "2017 Dystopia Residual"})
#      21 )
# ---> 23 timeseries = pd.merge(clean_data1, clean_data2, how="left", on="Country")
#      24 timeseries = (
#      25     pd.merge(timeseries, clean_data3, how="left", on="Country")
#      26     .dropna()
#    (...)
#      30     .drop(columns=["2015 Dystopia Residual", "2016 Dystopia Residual", "2017 Dystopia Residual"])
#      31 )
#      33 return timeseries
#
# NameError: name 'clean_data1' is not defined

# %%
timeseries = p2.load_and_process("../data/raw/2015.csv", "../data/raw/2016.csv", "../data/raw/2017.csv")

timeseries.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [310], line 1
# ----> 1 timeseries = p2.load_and_process("../data/raw/2015.csv", "../data/raw/2016.csv", "../data/raw/2017.csv")
#       3 timeseries.head()
#
# File c:\Users\athar\Documents\COSC 301\project-group41\notebooks\project_functions2.py:4, in load_and_process(file1, file2, file3)
#       1 def load_and_process(file1, file2, file3):
#       3     data1 = (
# ----> 4         pd.read_csv(f"{file1}")
#       5         .drop(columns=['Happiness Rank', 'Family', 'Health (Life Expectancy)', 'Freedom', "Generosity"])
#       6         .rename(columns={"Happiness Score": "2015 Score", "Economy (GDP per Capita)": "2015 GDP", "Trust (Government Corruption)": "2015 Trust", "Dystopia Residual": "2015 Dystopia Residual"})
#       7     )
#       9     data2 = (
#      10         pd.read_csv(f"{file2}")
#      11         .drop(columns=['Happiness Rank', 'Family', 'Health (Life Expectancy)', 'Freedom', "Generosity"])
#      12         .rename(columns={"Happiness Score": "2016 Score", "Economy (GDP per Capita)": "2016 GDP", "Trust (Government Corruption)": "2016 Trust", "Dystopia Residual": "2016 Dystopia Residual"})
#      13     )
#      15     data3 = (
#      16         pd.read_csv(f"{file3}")
#      17         .drop(columns=['Happiness Rank', 'Family', 'Health (Life Expectancy)', 'Freedom', "Generosity"])
#      18         .rename(columns={"Happiness Score": "2017 Score", "Economy (GDP per Capita)": "2017 GDP", "Trust (Government Corruption)": "2017 Trust", "Dystopia Residual": "2017 Dystopia Residual"})
#      19     )
#
# NameError: name 'pd' is not defined
